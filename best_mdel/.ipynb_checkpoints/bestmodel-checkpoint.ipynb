# %% [markdown]
# # Задача

# %% [markdown]
# ![задание](picture.png)

# %% [markdown]
# Технологии искусственного интеллекта трансформируют сферу управления персоналом, позволяя решать практические HR-задачи. Уже сейчас умные алгоритмы могут подобрать кадры, спланировать размер фонда заработной платы, выбрать образовательные курсы, оценить мотивацию, эффективность труда и даже спрогнозировать карьерное развитие специалиста.
#
# Аналитика по определению карьерной траектории строится, в том числе, на основе данных по использованию различных корпоративных информационных систем (система мониторинга рабочего времени, сервисы видеоконференции связи, IP-телефонии, СЭД, СКУД, электронная почта). Таким образом, для некоторых профессий, связанных с активным использованием электронных устройств (программист, бухгалтер, маркетолог и т.д.), можно выделить цифровой профиль успешных специалистов, выполняющих задачи своевременно и качественно и получающих новые должности.
#
# На основе совокупности информации о кадровых назначениях, активности и вовлеченности сотрудников в производственный процесс, участникам чемпионата нужно предложить алгоритм по прогнозу изменений должности работников.

# %% [markdown]
# ## Загрузим нужные библиотеки

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import recall_score
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import VotingClassifier
from sklearn.multiclass import OneVsRestClassifier
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %% [markdown]
# В начале остановимся на наиболее перспективных навыках

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")
df_calls = pd.read_csv("Calls.csv")
df_connection_time = pd.read_csv("ConnectionTime.csv")
df_ed = pd.read_csv("Education.csv")
df_tasks=pd.read_csv('Tasks.csv')
timennetwork=pd.read_csv('TimenNetwork.csv')
workingday=pd.read_csv("WorkingDay.csv")

# %%
df_train['type'].value_counts()
# Out:
# 2    298
# 0    153
# 1     74
# 3     25
# Name: type, dtype: int64

# %%
sns.countplot(x = "type" , data  = df_train).set_title('тип повышения')
plt.show()

# %% [markdown]
# ## Рассмотрим датасет по ближе

# %%
df_calls.head(3)
# Out:
#                       Date                CallTime  NumberOfCalls  \
# 0  2021-08-16 00:00:00,000  0,00027777777777777778              1
# 1  2021-09-21 00:00:00,000  0,00027777777777777778              1
# 2  2021-01-11 00:00:00,000  0,00027777777777777778              1
#
#   Вид учета времени   InOut          id
# 0             Будни  ToUser  ОРГ1-01945
# 1             Будни  ToUser  ОРГ1-01945
# 2             Будни  ToUser  ОРГ1-01945

# %%
df_connection_time.head(3)
# Out:
#                    dateNum                maxLogOff  \
# 0  2021-12-15 00:00:00,000  2021-12-15 17:30:27,246
# 1  2021-12-15 00:00:00,000  2021-12-15 16:30:13,330
# 2  2021-12-15 00:00:00,000  2021-12-15 15:27:37,246
#
#   Нормативное время начала раб.дня Фактич. время начала раб.дня  \
# 0          1899-12-30 08:30:00,000      1899-12-30 08:24:18,606
# 1          1899-12-30 08:30:00,000      1899-12-30 01:05:20,513
# 2          1899-12-30 08:30:00,000      1899-12-30 05:47:33,156
#
#   Время опоздания Признак опоздания Вых/Будни          id
# 0             NaN               NaN     Будни  ОРГ1-02782
# 1             NaN               NaN     Будни  ОРГ1-01407
# 2             NaN               NaN     Будни  ОРГ1-01909

# %%
df_connection_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230662 entries, 0 to 230661
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   dateNum                           230662 non-null  object
#  1   maxLogOff                         230662 non-null  object
#  2   Нормативное время начала раб.дня  230662 non-null  object
#  3   Фактич. время начала раб.дня      230662 non-null  object
#  4   Время опоздания                   103101 non-null  object
#  5   Признак опоздания                 77520 non-null   object
#  6   Вых/Будни                         230662 non-null  object
#  7   id                                230662 non-null  object
# dtypes: object(8)
# memory usage: 14.1+ MB

# %%
df_ed.head(3)
# Out:
#   Табельный номер руководителя          id  \
# 0                          NaN  ОРГ1-00131
# 1                          NaN  ОРГ1-03220
# 2                          NaN  ОРГ1-03008
#
#                         Вид образования  Специальность
# 0      Высшее образование - бакалавриат  Юриспруденция
# 1  Среднее профессиональное образование        Финансы
# 2                    Высшее образование  Юриспруденция

# %% [markdown]
# Узнаем размерность наборов

# %%
print("df_train", df_train.shape)
print("df_calls", df_calls.shape)
print("df_connection_time", df_connection_time.shape)
print("df_ed", df_ed.shape)
print("df_test", df_test.shape)
# Out:
# df_train (550, 2)
# df_calls (407867, 6)
# df_connection_time (230662, 8)
# df_ed (5609, 4)
# df_test (262, 2)

# %% [markdown]
# ### Видоизмение данных

# %% [markdown]
# Обьединим два набора с данными

# %%
df_train = pd.merge(df_train, df_ed , on="id", how='left').drop_duplicates(subset="id")

df_train.head(3)
# Out:
#            id  type Табельный номер руководителя              Вид образования  \
# 0  ОРГ1-02050     2                          NaN  Неполное высшее образование
# 2  ОРГ1-02783     2                   ОРГ1-01974           Высшее образование
# 3  ОРГ2-06173     0                   ОРГ2-01170           Высшее образование
#
#                                        Специальность
# 0              Технологические машины и оборудование
# 2  Автоматизация технологических процессов и прои...
# 3                               Управление качеством

# %%
df_train = df_train.drop(["Табельный номер руководителя", "Специальность"],axis = 1)
df_train["Вид образования"].value_counts()
# Out:
# Высшее образование                                297
# Среднее профессиональное образование               64
# Высшее образование - бакалавриат                   59
# Высшее образование - специалитет, магистратура     30
# Начальное профессиональное образование              7
# Повышение квалификации                              7
# Неполное высшее образование                         5
# Среднее общее образование                           3
# Среднее (полное) общее образование                  2
# Переподготовка                                      2
# Профессиональное обучение                           1
# Name: Вид образования, dtype: int64

# %%
edu_type=pd.DataFrame(df_train["Вид образования"].value_counts()).reset_index()
plt.figure(figsize=(30,10))
sns.set_context("paper", font_scale=2)
sns.set_theme(style="whitegrid")
sns.set(font_scale=2.5)
sns.barplot(x=edu_type['index'],y=edu_type['Вид образования'],data=edu_type, palette="Blues_d") 
plt.title('Виды документов', size=36)
plt.xlabel('Вид документа', size=36)
plt.ylabel('Количество', size=36)
plt.xticks(rotation=80)
plt.show()

# %%
df_train["Вид образования"] = df_train["Вид образования"].astype('category')
df_train["Вид образования"] = df_train["Вид образования"].cat.codes

# %% [markdown]
# Оставим только столбец - опоздания сотрудников

# %%
df_connection_time_res = df_connection_time[["id","Признак опоздания"]]
df_connection_time_res = df_connection_time_res[df_connection_time_res["Признак опоздания"].notna()]

df_connection_time_res.head()
# Out:
#                 id Признак опоздания
# 127561  ОРГ1-01589         Опоздание
# 127562  ОРГ1-01589         Опоздание
# 127563  ОРГ1-01589         Опоздание
# 127564  ОРГ1-01589         Опоздание
# 127565  ОРГ1-01589         Опоздание

# %%
df_connection_time_res = df_connection_time_res.groupby("id").count()
df_connection_time_res = df_connection_time_res.rename(columns={"Признак опоздания": "Число опозданий"})
df_connection_time_res.head(3)
# Out:
#             Число опозданий
# id
# ОРГ1-00004              275
# ОРГ1-00028               35
# ОРГ1-00030               57

# %%
df_train = pd.merge(df_train, df_connection_time_res , on="id", how='left')#.drop(["event_type"],axis =1)

df_train.head(3)
# Out:
#            id  type  Вид образования  Число опозданий
# 0  ОРГ1-02050     2                4              5.0
# 1  ОРГ1-02783     2                0              7.0
# 2  ОРГ2-06173     0                0             22.0

# %% [markdown]
# ## Добавим суммарное время звонков!

# %%
def str_to_float(str):
    if type(str)==float:
        return str
    str=str.replace(',','')
    return float(str)

df_calls['CallTime']=df_calls['CallTime'].map(str_to_float)
CallTime=pd.DataFrame(df_calls.groupby('id')['CallTime'].sum()).reset_index()
df_train = pd.merge(df_train, CallTime , on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
# [550 rows x 5 columns]

# %% [markdown]
# ## Добавим колличество звонков в будни и выходные

# %%
NumberOfCalls=pd.DataFrame(df_calls.groupby('id')['NumberOfCalls'].sum()).reset_index()
df_calls= df_calls.rename(columns={'Вид учета времени': 'statusworkfre'})

NumberOfCallsW=pd.DataFrame(df_calls.query("statusworkfre=='Будни'").groupby('id')['NumberOfCalls'].sum()).reset_index()
NumberOfCallsNW=pd.DataFrame(df_calls.query("statusworkfre=='Выходные дни'").groupby('id')['NumberOfCalls'].sum()).reset_index()
df_train = pd.merge(df_train, NumberOfCalls , on="id", how='left')
df_train = pd.merge(df_train, NumberOfCallsW , on="id", how='left')
df_train = pd.merge(df_train, NumberOfCallsNW , on="id", how='left')
df_train = df_train.rename(columns={'NumberOfCalls_x': 'NumberOfCalls_worck','NumberOfCalls_y': 'NumberOfCalls_free','NumberOfCalls': 'NumberOfCallsfreesum'})
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
# [550 rows x 8 columns]

# %% [markdown]
# ## Добавим колличество входящих и исходящих.

# %%
NumberToUser=pd.DataFrame(df_calls.query("InOut=='ToUser'").groupby('id')['NumberOfCalls'].sum()).reset_index()
NumberFromUser=pd.DataFrame(df_calls.query("InOut=='FromUser'").groupby('id')['NumberOfCalls'].sum()).reset_index() 
df_train = pd.merge(df_train, NumberToUser , on="id", how='left')
df_train = pd.merge(df_train, NumberFromUser , on="id", how='left')

# %% [markdown]
# ## Добавим суммарное время опазданий

# %%
df_connection_time['Время опоздания']=df_connection_time['Время опоздания'].map(str_to_float)
falout=pd.DataFrame(df_connection_time.groupby('id')['Время опоздания'].sum()).reset_index() 
df_train = pd.merge(df_train, falout , on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  Время опоздания
# 0              176.0            370.0     2.361381e+17
# 1              657.0           1245.0     2.532397e+17
# 2                NaN              NaN     1.200253e+18
# 3                NaN              NaN     1.657396e+17
# 4                1.0              6.0     9.288578e+17
# ..               ...              ...              ...
# 545              NaN              NaN              NaN
# 546           1692.0           2878.0     2.432262e+18
# 547              NaN              NaN              NaN
# 548           1088.0           2829.0     5.449973e+17
# 549              NaN              3.0              NaN
#
# [550 rows x 11 columns]

# %% [markdown]
# ## Добавим дельту прихода на работу

# %%
df_connection_time['Нормативное время начала раб.дня']=pd.to_datetime(df_connection_time['Нормативное время начала раб.дня'])
df_connection_time['Фактич. время начала раб.дня']=pd.to_datetime(df_connection_time['Фактич. время начала раб.дня'])
df_connection_time['filtime']=df_connection_time['Нормативное время начала раб.дня']-df_connection_time['Фактич. время начала раб.дня']
filtime=pd.DataFrame(df_connection_time.groupby('id')['filtime'].mean().dt.total_seconds()).reset_index()
df_train = pd.merge(df_train, filtime , on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  Время опоздания       filtime
# 0              176.0            370.0     2.361381e+17    276.332096
# 1              657.0           1245.0     2.532397e+17   -695.247628
# 2                NaN              NaN     1.200253e+18   -608.828839
# 3                NaN              NaN     1.657396e+17   2186.244912
# 4                1.0              6.0     9.288578e+17 -14381.555892
# ..               ...              ...              ...           ...
# 545              NaN              NaN              NaN           NaN
# 546           1692.0           2878.0     2.432262e+18  -7348.409864
# 547              NaN              NaN              NaN           NaN
# 548           1088.0           2829.0     5.449973e+17    -58.303964
# 549              NaN              3.0              NaN           NaN
#
# [550 rows x 12 columns]

# %% [markdown]
# ## Добавим Профессию

# %%
prof=pd.DataFrame(df_ed['Специальность'].value_counts()).reset_index()
profhed=prof.head(457)
profhed['profcod']=profhed.index
proftail=prof.tail(623)
proftail['profcod']=999
profhed=profhed.append(proftail)
profhed= profhed.rename(columns={'index': 'specialisation'})
uniq = profhed['specialisation'].values
fifa = profhed['profcod'].values
uniq_and_fifa = dict(zip(uniq, fifa))
uniq_and_fifa
df_ed['Специальность']=df_ed['Специальность'].map(uniq_and_fifa)
professionstart=df_ed[['id','Специальность']].groupby('id')['Специальность'].min()
professionend=df_ed[['id','Специальность']].groupby('id')['Специальность'].max()
df_train = pd.merge(df_train, professionstart , on="id", how='left')
df_train = pd.merge(df_train, professionend , on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  Время опоздания       filtime  \
# 0              176.0            370.0     2.361381e+17    276.332096
# 1              657.0           1245.0     2.532397e+17   -695.247628
# 2                NaN              NaN     1.200253e+18   -608.828839
# 3                NaN              NaN     1.657396e+17   2186.244912
# 4                1.0              6.0     9.288578e+17 -14381.555892
# ..               ...              ...              ...           ...
# 545              NaN              NaN              NaN           NaN
# 546           1692.0           2878.0     2.432262e+18  -7348.409864
# 547              NaN              NaN              NaN           NaN
# 548           1088.0           2829.0     5.449973e+17    -58.303964
# 549              NaN              3.0              NaN           NaN
#
#      Специальность_x  Специальность_y
# 0               21.0             21.0
# 1               16.0             16.0
# 2              116.0            116.0
# 3              999.0            999.0
# 4              365.0            365.0
# ..               ...              ...
# 545              NaN              NaN
# 546             24.0             24.0
# 547              NaN              NaN
# 548            136.0            160.0
# 549              NaN              NaN
#
# [550 rows x 14 columns]

# %% [markdown]
# ## Добавим rколичество  руководителей

# %%
df_ed
# Out:
#      Табельный номер руководителя          id  \
# 0                             NaN  ОРГ1-00131
# 1                             NaN  ОРГ1-03220
# 2                             NaN  ОРГ1-03008
# 3                             NaN  ОРГ1-00922
# 4                             NaN  ОРГ1-00922
# ...                           ...         ...
# 5604                   ОРГ2-09100  ОРГ2-08601
# 5605                   ОРГ2-09100  ОРГ2-08622
# 5606                   ОРГ2-09100  ОРГ2-04773
# 5607                   ОРГ2-09100  ОРГ2-05048
# 5608                   ОРГ2-09100  ОРГ2-02124
#
#                                      Вид образования  Специальность
# 0                   Высшее образование - бакалавриат            6.0
# 1               Среднее профессиональное образование          135.0
# 2                                 Высшее образование            6.0
# 3                   Высшее образование - бакалавриат          999.0
# 4                                 Высшее образование           35.0
# ...                                              ...            ...
# 5604          Начальное профессиональное образование           55.0
# 5605          Начальное профессиональное образование            NaN
# 5606            Среднее профессиональное образование          275.0
# 5607  Высшее образование - специалитет, магистратура          257.0
# 5608          Начальное профессиональное образование            NaN
#
# [5609 rows x 4 columns]

# %%
boss=df_ed.groupby('id')['Табельный номер руководителя'].count()

# %%
df_train = pd.merge(df_train, boss , on="id", how='left')

# %% [markdown]
# # Добавим колличество завершенных заданий

# %%
documents_type=pd.DataFrame(df_tasks['Вид документа'].value_counts()).reset_index()

# %%
plt.figure(figsize=(30,10))
sns.set_context("paper", font_scale=2)
sns.set_theme(style="whitegrid")
sns.set(font_scale=2.5)
sns.barplot(x=documents_type['index'],y=documents_type['Вид документа'],data=documents_type, palette="Blues_d") 
plt.title('Виды документов', size=36)
plt.xlabel('Вид документа', size=36)
plt.ylabel('Количество', size=36)
plt.xticks(rotation=90)
plt.show()

# %%
df_tasks.head(50)
# Out:
#     Статус по просрочке Срок плановый  Просрочено, дней ДлительностьПросрочки  \
# 0   Без нарушения срока           NaN                 0   без нарушения срока
# 1   Без нарушения срока           NaN                 0   без нарушения срока
# 2   Без нарушения срока           NaN                 0   без нарушения срока
# 3   Без нарушения срока           NaN                 0   без нарушения срока
# 4   Без нарушения срока           NaN                 0   без нарушения срока
# 5   Без нарушения срока           NaN                 0   без нарушения срока
# 6   Без нарушения срока           NaN                 0   без нарушения срока
# 7   Без нарушения срока           NaN                 0   без нарушения срока
# 8   Без нарушения срока           NaN                 0   без нарушения срока
# 9   Без нарушения срока           NaN                 0   без нарушения срока
# 10  Без нарушения срока           NaN                 0   без нарушения срока
# 11  Без нарушения срока           NaN                 0   без нарушения срока
# 12  Без нарушения срока           NaN                 0   без нарушения срока
# 13  Без нарушения срока           NaN                 0   без нарушения срока
# 14  Без нарушения срока           NaN                 0   без нарушения срока
# 15  Без нарушения срока           NaN                 0   без нарушения срока
# 16  Без нарушения срока           NaN                 0   без нарушения срока
# 17  Без нарушения срока           NaN                 0   без нарушения срока
# 18  Без нарушения срока           NaN                 0   без нарушения срока
# 19  Без нарушения срока           NaN                 0   без нарушения срока
# 20  Без нарушения срока           NaN                 0   без нарушения срока
# 21  Без нарушения срока           NaN                 0   без нарушения срока
# 22  Без нарушения срока           NaN                 0   без нарушения срока
# 23  Без нарушения срока           NaN                 0   без нарушения срока
# 24  Без нарушения срока           NaN                 0   без нарушения срока
# 25  Без нарушения срока           NaN                 0   без нарушения срока
# 26  Без нарушения срока           NaN                 0   без нарушения срока
# 27  Без нарушения срока           NaN                 0   без нарушения срока
# 28  Без нарушения срока           NaN                 0   без нарушения срока
# 29  Без нарушения срока           NaN                 0   без нарушения срока
# 30  Без нарушения срока           NaN                 0   без нарушения срока
# 31  Без нарушения срока           NaN                 0   без нарушения срока
# 32  Без нарушения срока           NaN                 0   без нарушения срока
# 33  Без нарушения срока           NaN                 0   без нарушения срока
# 34  Без нарушения срока           NaN                 0   без нарушения срока
# 35  Без нарушения срока           NaN                 0   без нарушения срока
# 36  Без нарушения срока           NaN                 0   без нарушения срока
# 37  Без нарушения срока           NaN                 0   без нарушения срока
# 38  Без нарушения срока           NaN                 0   без нарушения срока
# 39  Без нарушения срока           NaN                 0   без нарушения срока
# 40  Без нарушения срока           NaN                 0   без нарушения срока
# 41  Без нарушения срока           NaN                 0   без нарушения срока
# 42  Без нарушения срока           NaN                 0   без нарушения срока
# 43  Без нарушения срока           NaN                 0   без нарушения срока
# 44  Без нарушения срока           NaN                 0   без нарушения срока
# 45  Без нарушения срока           NaN                 0   без нарушения срока
# 46  Без нарушения срока           NaN                 0   без нарушения срока
# 47  Без нарушения срока           NaN                 0   без нарушения срока
# 48  Без нарушения срока           NaN                 0   без нарушения срока
# 49  Без нарушения срока           NaN                 0   без нарушения срока
#
#                                ID задачи      Вид документа  \
# 0   E1DE844D-EE2D-4C41-AEDF-93F246749F0E  Служебная записка
# 1   7A92343C-8C9A-46E7-AC81-8F50F95009D0  Служебная записка
# 2   5CE64E52-D2D1-4DCC-B2C8-34734AA39AC0  Служебная записка
# 3   7A28F3DD-983F-4127-AB7F-6EDB85A69F1C  Служебная записка
# 4   ABFFAF61-12D8-44C2-B1F6-8402D174889E  Служебная записка
# 5   F229CA53-B362-42D7-8B35-F969EB14F421  Служебная записка
# 6   BE9F1F9E-B665-4306-AAFA-38980940C6BF  Служебная записка
# 7   D805905B-7176-44DA-9BE4-413C87396AE6  Служебная записка
# 8   AF0D0B62-EA68-489A-8710-3025BECBE93B  Служебная записка
# 9   5B267180-9C99-4326-9A2C-F0E5ECC12C7C  Служебная записка
# 10  6A5C3D91-3294-46DB-9EFD-DC47FADB6E4D  Служебная записка
# 11  101D36AE-C73B-43D5-8FF6-916909D537A9  Служебная записка
# 12  7A67C717-2CCF-4C83-B254-3D4449732414  Служебная записка
# 13  E729A6F7-F6BB-47EA-A1F1-824DE59F22C2  Служебная записка
# 14  3BE3E04B-3913-4E78-A01A-2B3E5DD449CC  Служебная записка
# 15  6242E6C6-1D8B-4866-839A-BE1B8D32EEC4  Служебная записка
# 16  C8E8777B-FE8E-4E45-8F00-BFDFB0D545C1  Служебная записка
# 17  7748D7D6-C5B7-4AC1-97A3-CD18AEF84DE9  Служебная записка
# 18  FBDC1BA9-5023-4B99-8F64-14AF84E8023B  Служебная записка
# 19  93D67008-E9D6-4942-93AC-B5CAA0F95A46  Служебная записка
# 20  0A990A40-D173-4F23-B98A-1A7764593013  Служебная записка
# 21  5CC95356-F194-40A1-866E-558AA5DA48E4  Служебная записка
# 22  7B09B087-7BE0-44FE-A91D-A270DB2C790A  Служебная записка
# 23  F11E8EB1-5D20-401C-9A6D-63B79F0BB730  Служебная записка
# 24  2A29CCD2-4D78-4CEA-871F-6A2F5D979508  Служебная записка
# 25  EAC581F3-5821-44FF-B1E3-71DA3769913E  Служебная записка
# 26  6774F3DA-E023-4030-BD97-8635B1E7581E  Служебная записка
# 27  6C4FCD98-BAF0-4DDD-B0AC-2E8702E08B23  Служебная записка
# 28  9FDACBC0-351C-4945-82E4-170B7FD81DA2  Служебная записка
# 29  2800637F-8045-438D-9310-022180FE119A  Служебная записка
# 30  4FDF4A66-16ED-4EC2-AFAB-6D95DDA046C2  Служебная записка
# 31  E18C5C08-2371-4279-96A5-27B7D1A1C576  Служебная записка
# 32  D7B1C407-C6C1-4BB5-BF5F-1CE385443463  Служебная записка
# 33  1B938800-F256-4E70-8639-ABBBD69041A2  Служебная записка
# 34  A32957EB-5918-429A-B28C-C3CA9EFD665F  Служебная записка
# 35  BF982D59-41FD-4B9E-8B57-A42F9016FFE7  Служебная записка
# 36  DDC7057A-49C7-4123-BDE2-D420620A0D9D  Служебная записка
# 37  790482F4-A609-4665-9A91-8C57C7CEB157  Служебная записка
# 38  44116E20-58B6-4B0E-A5DF-6EADFF526245  Служебная записка
# 39  B7E26448-CD9F-42FE-A22F-DE701E31B51F  Служебная записка
# 40  FBEE345C-4397-4D44-A4C7-87BF5E3BABC7  Служебная записка
# 41  284B3346-4E47-4883-A99B-A96F4767DBFB  Служебная записка
# 42  C699BD0A-9144-4BAD-B049-1BED9FA17255  Служебная записка
# 43  20275889-2662-4316-A068-175CCC9C16FE  Служебная записка
# 44  BC63DC9B-3BE1-40C7-9826-EF233DC04306  Служебная записка
# 45  26FB9084-EE33-4402-8ED9-05CD09996A04  Служебная записка
# 46  6F09E296-9754-4771-9A2E-67A2DB31885C  Служебная записка
# 47  DF9511AC-19CD-4E82-960E-97CD65BB0F4E  Служебная записка
# 48  240A8AF9-29E7-4420-8320-E0DD6C5620DA  Служебная записка
# 49  49C1D70D-F939-45BC-879F-4820BBED1F4B  Служебная записка
#
#         Дата старта задания Дата завершения задания плановая  \
# 0   2021-12-10 00:00:00,000                              NaN
# 1   2021-12-10 00:00:00,000                              NaN
# 2   2021-12-10 00:00:00,000                              NaN
# 3   2021-12-10 00:00:00,000                              NaN
# 4   2021-12-10 00:00:00,000                              NaN
# 5   2021-12-10 00:00:00,000                              NaN
# 6   2021-12-10 00:00:00,000                              NaN
# 7   2021-12-10 00:00:00,000                              NaN
# 8   2021-12-10 00:00:00,000                              NaN
# 9   2021-12-10 00:00:00,000                              NaN
# 10  2021-12-10 00:00:00,000                              NaN
# 11  2021-12-10 00:00:00,000                              NaN
# 12  2021-12-10 00:00:00,000                              NaN
# 13  2021-12-10 00:00:00,000                              NaN
# 14  2021-12-10 00:00:00,000                              NaN
# 15  2021-12-10 00:00:00,000                              NaN
# 16  2021-12-10 00:00:00,000                              NaN
# 17  2021-12-10 00:00:00,000                              NaN
# 18  2021-12-10 00:00:00,000                              NaN
# 19  2021-12-10 00:00:00,000                              NaN
# 20  2021-12-10 00:00:00,000                              NaN
# 21  2021-12-10 00:00:00,000                              NaN
# 22  2021-12-10 00:00:00,000                              NaN
# 23  2021-12-10 00:00:00,000                              NaN
# 24  2021-12-10 00:00:00,000                              NaN
# 25  2021-12-10 00:00:00,000                              NaN
# 26  2021-12-10 00:00:00,000                              NaN
# 27  2021-12-10 00:00:00,000                              NaN
# 28  2021-12-10 00:00:00,000                              NaN
# 29  2021-12-10 00:00:00,000                              NaN
# 30  2021-12-10 00:00:00,000                              NaN
# 31  2021-12-10 00:00:00,000                              NaN
# 32  2021-12-10 00:00:00,000                              NaN
# 33  2021-12-10 00:00:00,000                              NaN
# 34  2021-12-10 00:00:00,000                              NaN
# 35  2021-12-10 00:00:00,000                              NaN
# 36  2021-12-10 00:00:00,000                              NaN
# 37  2021-12-10 00:00:00,000                              NaN
# 38  2021-12-10 00:00:00,000                              NaN
# 39  2021-12-10 00:00:00,000                              NaN
# 40  2021-12-10 00:00:00,000                              NaN
# 41  2021-12-10 00:00:00,000                              NaN
# 42  2021-12-10 00:00:00,000                              NaN
# 43  2021-12-10 00:00:00,000                              NaN
# 44  2021-12-10 00:00:00,000                              NaN
# 45  2021-12-10 00:00:00,000                              NaN
# 46  2021-12-10 00:00:00,000                              NaN
# 47  2021-12-10 00:00:00,000                              NaN
# 48  2021-12-10 00:00:00,000                              NaN
# 49  2021-12-10 00:00:00,000                              NaN
#
#    Дата завершения задания фактическая Состояние задания          id
# 0              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 1              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 2              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 3              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 4              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 5              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 6              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 7              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 8              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 9              2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 10             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 11             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 12             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 13             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 14             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 15             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 16             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 17             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 18             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 19             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 20             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 21             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 22             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 23             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 24             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 25             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 26             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 27             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 28             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 29             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 30             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 31             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 32             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 33             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 34             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 35             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 36             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 37             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 38             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 39             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 40             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 41             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 42             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 43             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 44             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 45             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 46             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 47             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 48             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588
# 49             2021-12-10 00:00:00,000         Завершено  ОРГ1-02588

# %%
df_tasks['2']=str(df_tasks['ID задачи'])
df_tasks
# Out:
#         Статус по просрочке Срок плановый  Просрочено, дней  \
# 0       Без нарушения срока           NaN                 0
# 1       Без нарушения срока           NaN                 0
# 2       Без нарушения срока           NaN                 0
# 3       Без нарушения срока           NaN                 0
# 4       Без нарушения срока           NaN                 0
# ...                     ...           ...               ...
# 536655  Без нарушения срока           NaN                 0
# 536656  Без нарушения срока           NaN                 0
# 536657  Без нарушения срока           NaN                 0
# 536658  Без нарушения срока           NaN                 0
# 536659  Без нарушения срока           NaN                 0
#
#        ДлительностьПросрочки                             ID задачи  \
# 0        без нарушения срока  E1DE844D-EE2D-4C41-AEDF-93F246749F0E
# 1        без нарушения срока  7A92343C-8C9A-46E7-AC81-8F50F95009D0
# 2        без нарушения срока  5CE64E52-D2D1-4DCC-B2C8-34734AA39AC0
# 3        без нарушения срока  7A28F3DD-983F-4127-AB7F-6EDB85A69F1C
# 4        без нарушения срока  ABFFAF61-12D8-44C2-B1F6-8402D174889E
# ...                      ...                                   ...
# 536655   без нарушения срока  9FE7B014-3015-4855-BD08-D3C5260FB122
# 536656   без нарушения срока  B4A7AE02-2D7E-4D56-A337-0F14C27A85CC
# 536657   без нарушения срока  698F3F66-37BA-4042-BDE9-5F8C8BEA7FA6
# 536658   без нарушения срока  A7D0F2FA-9C2A-4F4D-A990-ABE463A5F0D5
# 536659   без нарушения срока  B6998E25-9E59-4428-A013-32BA99E5C6BD
#
#             Вид документа      Дата старта задания  \
# 0       Служебная записка  2021-12-10 00:00:00,000
# 1       Служебная записка  2021-12-10 00:00:00,000
# 2       Служебная записка  2021-12-10 00:00:00,000
# 3       Служебная записка  2021-12-10 00:00:00,000
# 4       Служебная записка  2021-12-10 00:00:00,000
# ...                   ...                      ...
# 536655  Служебная записка  2021-10-31 00:00:00,000
# 536656  Служебная записка  2021-10-31 00:00:00,000
# 536657  Служебная записка  2021-10-31 00:00:00,000
# 536658  Служебная записка  2021-10-30 00:00:00,000
# 536659  Служебная записка  2021-10-30 00:00:00,000
#
#        Дата завершения задания плановая Дата завершения задания фактическая  \
# 0                                   NaN             2021-12-10 00:00:00,000
# 1                                   NaN             2021-12-10 00:00:00,000
# 2                                   NaN             2021-12-10 00:00:00,000
# 3                                   NaN             2021-12-10 00:00:00,000
# 4                                   NaN             2021-12-10 00:00:00,000
# ...                                 ...                                 ...
# 536655          2021-11-01 00:00:00,000             2021-10-31 00:00:00,000
# 536656          2021-11-01 00:00:00,000             2021-10-31 00:00:00,000
# 536657          2021-11-01 00:00:00,000             2021-10-31 00:00:00,000
# 536658          2021-11-01 00:00:00,000             2021-10-31 00:00:00,000
# 536659          2021-11-01 00:00:00,000             2021-10-31 00:00:00,000
#
#        Состояние задания          id  \
# 0              Завершено  ОРГ1-02588
# 1              Завершено  ОРГ1-02588
# 2              Завершено  ОРГ1-02588
# 3              Завершено  ОРГ1-02588
# 4              Завершено  ОРГ1-02588
# ...                  ...         ...
# 536655         Завершено  ОРГ2-02838
# 536656         Завершено  ОРГ2-02838
# 536657         Завершено  ОРГ2-02838
# 536658         Завершено  ОРГ2-02838
# 536659         Завершено  ОРГ2-02838
#
#                                                         2
# 0       0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# 1       0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# 2       0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# 3       0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# 4       0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# ...                                                   ...
# 536655  0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# 536656  0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# 536657  0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# 536658  0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
# 536659  0         E1DE844D-EE2D-4C41-AEDF-93F246749F0E...
#
# [536660 rows x 12 columns]

# %%
df_tasks['Статус по просрочке'].value_counts()
temp_type=pd.DataFrame(df_tasks['Статус по просрочке'].value_counts()).reset_index()

# %%
plt.figure(figsize=(30,10))
sns.set_context("paper", font_scale=2)
sns.set_theme(style="whitegrid")
sns.set(font_scale=2.5)
sns.barplot(x=temp_type['index'],y=temp_type['Статус по просрочке'],data=temp_type, palette="Blues_d") 
plt.title('Статус просрочки', size=36)
plt.xlabel('статус', size=36)
plt.ylabel('Количество', size=36)
plt.xticks(rotation=90)
plt.show()

# %%
df_tasks = df_tasks.rename(columns={'Состояние задания': 'status_mission_count','Статус по просрочке':'статус_просрочек'})
status_mission_count=pd.DataFrame(df_tasks.query("status_mission_count=='Завершено'").groupby('id')['status_mission_count'].count()).reset_index().rename(columns={'status_mission_count': 'завершено'})
df_train = pd.merge(df_train,status_mission_count, on="id", how='left')

# %% [markdown]
# # Добавим колличество заданий в работе.

# %%
status_mission_count_in=pd.DataFrame(df_tasks.query("status_mission_count=='В работе'").groupby('id')['status_mission_count'].count()).reset_index().rename(columns={'status_mission_count': 'вработе'})
df_train = pd.merge(df_train,status_mission_count_in, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  Время опоздания       filtime  \
# 0              176.0            370.0     2.361381e+17    276.332096
# 1              657.0           1245.0     2.532397e+17   -695.247628
# 2                NaN              NaN     1.200253e+18   -608.828839
# 3                NaN              NaN     1.657396e+17   2186.244912
# 4                1.0              6.0     9.288578e+17 -14381.555892
# ..               ...              ...              ...           ...
# 545              NaN              NaN              NaN           NaN
# 546           1692.0           2878.0     2.432262e+18  -7348.409864
# 547              NaN              NaN              NaN           NaN
# 548           1088.0           2829.0     5.449973e+17    -58.303964
# 549              NaN              3.0              NaN           NaN
#
#      Специальность_x  Специальность_y  Табельный номер руководителя  \
# 0               21.0             21.0                           0.0
# 1               16.0             16.0                           1.0
# 2              116.0            116.0                           1.0
# 3              999.0            999.0                           1.0
# 4              365.0            365.0                           0.0
# ..               ...              ...                           ...
# 545              NaN              NaN                           NaN
# 546             24.0             24.0                           0.0
# 547              NaN              NaN                           NaN
# 548            136.0            160.0                           0.0
# 549              NaN              NaN                           NaN
#
#      завершено  вработе
# 0          1.0      NaN
# 1        306.0      NaN
# 2          NaN      NaN
# 3          NaN      NaN
# 4        155.0      NaN
# ..         ...      ...
# 545      123.0      NaN
# 546      102.0      3.0
# 547        NaN      NaN
# 548       33.0      NaN
# 549     8835.0     17.0
#
# [550 rows x 17 columns]

# %%
df_tasks['status_mission_count'].value_counts()
# Out:
# Завершено                  520779
# Не начато                    7842
# В работе                     7571
# Делегировано                  344
# На приёмке                     60
# Отложено                       55
# Возврат с делегирования         9
# Name: status_mission_count, dtype: int64

# %% [markdown]
# # Добавим задания в работе по месяцам.

# %%
df_tasks['monthstart']=pd.to_datetime(df_tasks['Дата старта задания']).dt.month
for i in range(1,13):
    tasks_month_sum_start=pd.DataFrame(df_tasks.query("status_mission_count=='В работе'").query('monthstart==@i').groupby('id')['Дата старта задания'].nunique()).rename(columns={'Дата старта задания': 'tasks_month_sum_start'+ str(i)})
    df_train = pd.merge(df_train,tasks_month_sum_start, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  tasks_month_sum_start3  \
# 0              176.0            370.0  ...                     NaN
# 1              657.0           1245.0  ...                     NaN
# 2                NaN              NaN  ...                     NaN
# 3                NaN              NaN  ...                     NaN
# 4                1.0              6.0  ...                     NaN
# ..               ...              ...  ...                     ...
# 545              NaN              NaN  ...                     NaN
# 546           1692.0           2878.0  ...                     NaN
# 547              NaN              NaN  ...                     NaN
# 548           1088.0           2829.0  ...                     NaN
# 549              NaN              3.0  ...                     1.0
#
#      tasks_month_sum_start4  tasks_month_sum_start5  tasks_month_sum_start6  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 545                     NaN                     NaN                     NaN
# 546                     NaN                     NaN                     NaN
# 547                     NaN                     NaN                     NaN
# 548                     NaN                     NaN                     NaN
# 549                     NaN                     NaN                     NaN
#
#      tasks_month_sum_start7  tasks_month_sum_start8  tasks_month_sum_start9  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# ..                      ...                     ...                     ...
# 545                     NaN                     NaN                     NaN
# 546                     NaN                     NaN                     NaN
# 547                     NaN                     NaN                     NaN
# 548                     NaN                     NaN                     NaN
# 549                     1.0                     3.0                     2.0
#
#      tasks_month_sum_start10  tasks_month_sum_start11  tasks_month_sum_start12
# 0                        NaN                      NaN                      NaN
# 1                        NaN                      NaN                      NaN
# 2                        NaN                      NaN                      NaN
# 3                        NaN                      NaN                      NaN
# 4                        NaN                      NaN                      NaN
# ..                       ...                      ...                      ...
# 545                      NaN                      NaN                      NaN
# 546                      NaN                      NaN                      2.0
# 547                      NaN                      NaN                      NaN
# 548                      NaN                      NaN                      NaN
# 549                      3.0                      1.0                      3.0
#
# [550 rows x 29 columns]

# %% [markdown]
# # Добавим количество заданий завершено по месяцам.

# %%
for i in range(1,13):
    tasks_month_sum_end=pd.DataFrame(df_tasks.query("status_mission_count=='Завершено'").query('monthstart==@i').groupby('id')['Дата старта задания'].nunique()).rename(columns={'Дата старта задания': 'tasks_month_sum_end'+ str(i)})
    df_train = pd.merge(df_train,tasks_month_sum_end, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  tasks_month_sum_end3  \
# 0              176.0            370.0  ...                   NaN
# 1              657.0           1245.0  ...                   NaN
# 2                NaN              NaN  ...                   NaN
# 3                NaN              NaN  ...                   NaN
# 4                1.0              6.0  ...                   6.0
# ..               ...              ...  ...                   ...
# 545              NaN              NaN  ...                   6.0
# 546           1692.0           2878.0  ...                  10.0
# 547              NaN              NaN  ...                   NaN
# 548           1088.0           2829.0  ...                   2.0
# 549              NaN              3.0  ...                  24.0
#
#      tasks_month_sum_end4  tasks_month_sum_end5  tasks_month_sum_end6  \
# 0                     NaN                   NaN                   NaN
# 1                     NaN                   3.0                   8.0
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                    12.0                   5.0                   5.0
# ..                    ...                   ...                   ...
# 545                   7.0                   2.0                   9.0
# 546                  11.0                   2.0                   7.0
# 547                   NaN                   NaN                   NaN
# 548                   1.0                   NaN                   1.0
# 549                  24.0                  22.0                  23.0
#
#      tasks_month_sum_end7  tasks_month_sum_end8  tasks_month_sum_end9  \
# 0                     NaN                   NaN                   NaN
# 1                    14.0                  14.0                  19.0
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                    12.0                  10.0                  10.0
# ..                    ...                   ...                   ...
# 545                  10.0                   9.0                   5.0
# 546                   7.0                   3.0                   1.0
# 547                   NaN                   NaN                   NaN
# 548                   NaN                   1.0                   NaN
# 549                  25.0                  26.0                  27.0
#
#      tasks_month_sum_end10  tasks_month_sum_end11  tasks_month_sum_end12
# 0                      NaN                    NaN                    NaN
# 1                     10.0                   13.0                   10.0
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                     15.0                   10.0                   15.0
# ..                     ...                    ...                    ...
# 545                    4.0                    7.0                    3.0
# 546                    7.0                    4.0                   16.0
# 547                    NaN                    NaN                    NaN
# 548                    NaN                    3.0                    9.0
# 549                   27.0                   22.0                   31.0
#
# [550 rows x 41 columns]

# %% [markdown]
# # Добавим колличество заданий Не начато

# %%
status_mission_count_nn=pd.DataFrame(df_tasks.query("status_mission_count=='Не начато'").groupby('id')['status_mission_count'].count()).reset_index().rename(columns={'status_mission_count': 'неначато'})
df_train = pd.merge(df_train,status_mission_count_nn, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  tasks_month_sum_end4  \
# 0              176.0            370.0  ...                   NaN
# 1              657.0           1245.0  ...                   NaN
# 2                NaN              NaN  ...                   NaN
# 3                NaN              NaN  ...                   NaN
# 4                1.0              6.0  ...                  12.0
# ..               ...              ...  ...                   ...
# 545              NaN              NaN  ...                   7.0
# 546           1692.0           2878.0  ...                  11.0
# 547              NaN              NaN  ...                   NaN
# 548           1088.0           2829.0  ...                   1.0
# 549              NaN              3.0  ...                  24.0
#
#      tasks_month_sum_end5  tasks_month_sum_end6  tasks_month_sum_end7  \
# 0                     NaN                   NaN                   NaN
# 1                     3.0                   8.0                  14.0
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     5.0                   5.0                  12.0
# ..                    ...                   ...                   ...
# 545                   2.0                   9.0                  10.0
# 546                   2.0                   7.0                   7.0
# 547                   NaN                   NaN                   NaN
# 548                   NaN                   1.0                   NaN
# 549                  22.0                  23.0                  25.0
#
#      tasks_month_sum_end8  tasks_month_sum_end9  tasks_month_sum_end10  \
# 0                     NaN                   NaN                    NaN
# 1                    14.0                  19.0                   10.0
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                    10.0                  10.0                   15.0
# ..                    ...                   ...                    ...
# 545                   9.0                   5.0                    4.0
# 546                   3.0                   1.0                    7.0
# 547                   NaN                   NaN                    NaN
# 548                   1.0                   NaN                    NaN
# 549                  26.0                  27.0                   27.0
#
#      tasks_month_sum_end11  tasks_month_sum_end12  неначато
# 0                      NaN                    NaN       NaN
# 1                     13.0                   10.0       NaN
# 2                      NaN                    NaN       NaN
# 3                      NaN                    NaN       NaN
# 4                     10.0                   15.0       4.0
# ..                     ...                    ...       ...
# 545                    7.0                    3.0      16.0
# 546                    4.0                   16.0       NaN
# 547                    NaN                    NaN       NaN
# 548                    3.0                    9.0       NaN
# 549                   22.0                   31.0       NaN
#
# [550 rows x 42 columns]

# %% [markdown]
# # Задания делегировано по месяцам

# %%
for i in range(1,13):
    tasks_month_sum_startn=pd.DataFrame(df_tasks.query("status_mission_count=='Делегировано'").query('monthstart==@i').groupby('id')['Дата старта задания'].nunique()).rename(columns={'Дата старта задания': 'tasks_month_sum_startn'+ str(i)})
    df_train = pd.merge(df_train,tasks_month_sum_startn, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  tasks_month_sum_startn3  \
# 0              176.0            370.0  ...                      NaN
# 1              657.0           1245.0  ...                      NaN
# 2                NaN              NaN  ...                      NaN
# 3                NaN              NaN  ...                      NaN
# 4                1.0              6.0  ...                      NaN
# ..               ...              ...  ...                      ...
# 545              NaN              NaN  ...                      NaN
# 546           1692.0           2878.0  ...                      NaN
# 547              NaN              NaN  ...                      NaN
# 548           1088.0           2829.0  ...                      NaN
# 549              NaN              3.0  ...                      NaN
#
#      tasks_month_sum_startn4  tasks_month_sum_startn5  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn6  tasks_month_sum_startn7  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        1.0                      NaN
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn8  tasks_month_sum_startn9  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn10  tasks_month_sum_startn11  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ..                        ...                       ...
# 545                       NaN                       NaN
# 546                       NaN                       NaN
# 547                       NaN                       NaN
# 548                       NaN                       NaN
# 549                       NaN                       NaN
#
#      tasks_month_sum_startn12
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 545                       NaN
# 546                       NaN
# 547                       NaN
# 548                       NaN
# 549                       NaN
#
# [550 rows x 54 columns]

# %% [markdown]
# # Добавим колличество заданий делегировано

# %%
status_mission_count_d=pd.DataFrame(df_tasks.query("status_mission_count=='Делегировано'").groupby('id')['status_mission_count'].count()).reset_index().rename(columns={'status_mission_count': 'делегировано'})
df_train = pd.merge(df_train,status_mission_count_d, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  tasks_month_sum_startn4  \
# 0              176.0            370.0  ...                      NaN
# 1              657.0           1245.0  ...                      NaN
# 2                NaN              NaN  ...                      NaN
# 3                NaN              NaN  ...                      NaN
# 4                1.0              6.0  ...                      NaN
# ..               ...              ...  ...                      ...
# 545              NaN              NaN  ...                      NaN
# 546           1692.0           2878.0  ...                      NaN
# 547              NaN              NaN  ...                      NaN
# 548           1088.0           2829.0  ...                      NaN
# 549              NaN              3.0  ...                      NaN
#
#      tasks_month_sum_startn5  tasks_month_sum_startn6  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      1.0
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn7  tasks_month_sum_startn8  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn9  tasks_month_sum_startn10  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 545                      NaN                       NaN
# 546                      NaN                       NaN
# 547                      NaN                       NaN
# 548                      NaN                       NaN
# 549                      NaN                       NaN
#
#      tasks_month_sum_startn11  tasks_month_sum_startn12  делегировано
# 0                         NaN                       NaN           NaN
# 1                         NaN                       NaN           NaN
# 2                         NaN                       NaN           NaN
# 3                         NaN                       NaN           NaN
# 4                         NaN                       NaN           1.0
# ..                        ...                       ...           ...
# 545                       NaN                       NaN           NaN
# 546                       NaN                       NaN           NaN
# 547                       NaN                       NaN           NaN
# 548                       NaN                       NaN           NaN
# 549                       NaN                       NaN           NaN
#
# [550 rows x 55 columns]

# %% [markdown]
# # Добавим колличество заданий На приёмке

# %%
status_mission_count_p=pd.DataFrame(df_tasks.query("status_mission_count=='На приёмке'").groupby('id')['status_mission_count'].count()).reset_index().rename(columns={'status_mission_count': 'наприемке'})
df_train = pd.merge(df_train,status_mission_count_p, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  tasks_month_sum_startn5  \
# 0              176.0            370.0  ...                      NaN
# 1              657.0           1245.0  ...                      NaN
# 2                NaN              NaN  ...                      NaN
# 3                NaN              NaN  ...                      NaN
# 4                1.0              6.0  ...                      NaN
# ..               ...              ...  ...                      ...
# 545              NaN              NaN  ...                      NaN
# 546           1692.0           2878.0  ...                      NaN
# 547              NaN              NaN  ...                      NaN
# 548           1088.0           2829.0  ...                      NaN
# 549              NaN              3.0  ...                      NaN
#
#      tasks_month_sum_startn6  tasks_month_sum_startn7  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        1.0                      NaN
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn8  tasks_month_sum_startn9  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn10  tasks_month_sum_startn11  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ..                        ...                       ...
# 545                       NaN                       NaN
# 546                       NaN                       NaN
# 547                       NaN                       NaN
# 548                       NaN                       NaN
# 549                       NaN                       NaN
#
#      tasks_month_sum_startn12  делегировано  наприемке
# 0                         NaN           NaN        NaN
# 1                         NaN           NaN        NaN
# 2                         NaN           NaN        NaN
# 3                         NaN           NaN        NaN
# 4                         NaN           1.0        NaN
# ..                        ...           ...        ...
# 545                       NaN           NaN        NaN
# 546                       NaN           NaN        NaN
# 547                       NaN           NaN        NaN
# 548                       NaN           NaN        NaN
# 549                       NaN           NaN        1.0
#
# [550 rows x 56 columns]

# %% [markdown]
# # Добавим колличество заданий Отложено

# %%
status_mission_count_o=pd.DataFrame(df_tasks.query("status_mission_count=='Отложено'").groupby('id')['status_mission_count'].count()).reset_index().rename(columns={'status_mission_count': 'Отложено'})
df_train = pd.merge(df_train,status_mission_count_o, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  tasks_month_sum_startn6  \
# 0              176.0            370.0  ...                      NaN
# 1              657.0           1245.0  ...                      NaN
# 2                NaN              NaN  ...                      NaN
# 3                NaN              NaN  ...                      NaN
# 4                1.0              6.0  ...                      1.0
# ..               ...              ...  ...                      ...
# 545              NaN              NaN  ...                      NaN
# 546           1692.0           2878.0  ...                      NaN
# 547              NaN              NaN  ...                      NaN
# 548           1088.0           2829.0  ...                      NaN
# 549              NaN              3.0  ...                      NaN
#
#      tasks_month_sum_startn7  tasks_month_sum_startn8  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn9  tasks_month_sum_startn10  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 545                      NaN                       NaN
# 546                      NaN                       NaN
# 547                      NaN                       NaN
# 548                      NaN                       NaN
# 549                      NaN                       NaN
#
#      tasks_month_sum_startn11  tasks_month_sum_startn12  делегировано  \
# 0                         NaN                       NaN           NaN
# 1                         NaN                       NaN           NaN
# 2                         NaN                       NaN           NaN
# 3                         NaN                       NaN           NaN
# 4                         NaN                       NaN           1.0
# ..                        ...                       ...           ...
# 545                       NaN                       NaN           NaN
# 546                       NaN                       NaN           NaN
# 547                       NaN                       NaN           NaN
# 548                       NaN                       NaN           NaN
# 549                       NaN                       NaN           NaN
#
#      наприемке  Отложено
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ..         ...       ...
# 545        NaN       NaN
# 546        NaN       NaN
# 547        NaN       NaN
# 548        NaN       NaN
# 549        1.0       NaN
#
# [550 rows x 57 columns]

# %% [markdown]
# ## Добавим сумму просрочки дней!

# %%
day_ful_mission=pd.DataFrame(df_tasks.groupby('id')['Просрочено, дней'].sum()).reset_index().rename(columns={'Просрочено, дней': 'просрочено всего'})
df_train = pd.merge(df_train,day_ful_mission, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  tasks_month_sum_startn7  \
# 0              176.0            370.0  ...                      NaN
# 1              657.0           1245.0  ...                      NaN
# 2                NaN              NaN  ...                      NaN
# 3                NaN              NaN  ...                      NaN
# 4                1.0              6.0  ...                      NaN
# ..               ...              ...  ...                      ...
# 545              NaN              NaN  ...                      NaN
# 546           1692.0           2878.0  ...                      NaN
# 547              NaN              NaN  ...                      NaN
# 548           1088.0           2829.0  ...                      NaN
# 549              NaN              3.0  ...                      NaN
#
#      tasks_month_sum_startn8  tasks_month_sum_startn9  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 545                      NaN                      NaN
# 546                      NaN                      NaN
# 547                      NaN                      NaN
# 548                      NaN                      NaN
# 549                      NaN                      NaN
#
#      tasks_month_sum_startn10  tasks_month_sum_startn11  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ..                        ...                       ...
# 545                       NaN                       NaN
# 546                       NaN                       NaN
# 547                       NaN                       NaN
# 548                       NaN                       NaN
# 549                       NaN                       NaN
#
#      tasks_month_sum_startn12  делегировано  наприемке  Отложено  \
# 0                         NaN           NaN        NaN       NaN
# 1                         NaN           NaN        NaN       NaN
# 2                         NaN           NaN        NaN       NaN
# 3                         NaN           NaN        NaN       NaN
# 4                         NaN           1.0        NaN       NaN
# ..                        ...           ...        ...       ...
# 545                       NaN           NaN        NaN       NaN
# 546                       NaN           NaN        NaN       NaN
# 547                       NaN           NaN        NaN       NaN
# 548                       NaN           NaN        NaN       NaN
# 549                       NaN           NaN        1.0       NaN
#
#      просрочено всего
# 0                 0.0
# 1               861.0
# 2                 NaN
# 3                 NaN
# 4              1976.0
# ..                ...
# 545            3656.0
# 546           12199.0
# 547               NaN
# 548              53.0
# 549            9111.0
#
# [550 rows x 58 columns]

# %% [markdown]
# # Добавим статус по просрочке с нарушением без науршения и их отношение.

# %%
fail_count_b=pd.DataFrame(df_tasks.query('статус_просрочек=="Без нарушения срока"').groupby('id')['статус_просрочек'].count())
fail_count_p=pd.DataFrame(df_tasks.query('статус_просрочек=="С нарушением срока"').groupby('id')['статус_просрочек'].count()).rename(columns={'статус_просрочек': 'просрочено'})
df_train = pd.merge(df_train,fail_count_b, on="id", how='left')
df_train = pd.merge(df_train,fail_count_p, on="id", how='left')
df_train['bp']=df_train['статус_просрочек']/df_train['просрочено']

# %% [markdown]
# # Добавим общее время активности в сети

# %%
timennetwork_time=pd.DataFrame(timennetwork.groupby('id')['monitor_Time'].sum())
df_train = pd.merge(df_train,timennetwork_time, on="id", how='left')

# %% [markdown]
# # Добавим среднее время простоя монитора

# %%
workingday['monitorTime_mean']=workingday['monitorTime']-workingday['activeTime']
monitor_stop=pd.DataFrame(workingday.groupby('id')['monitorTime_mean'].mean())
df_train = pd.merge(df_train,monitor_stop, on="id", how='left')

# %% [markdown]
# # Добавим счетчик начал рабочего дня

# %%
df_connection_time=df_connection_time.rename(columns={'Нормативное время начала раб.дня': 'начало_дня'})
start_day=pd.DataFrame(df_connection_time.groupby('id')['начало_дня'].count())
df_train = pd.merge(df_train,start_day, on="id", how='left')

# %%
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  делегировано  наприемке  Отложено  \
# 0              176.0            370.0  ...           NaN        NaN       NaN
# 1              657.0           1245.0  ...           NaN        NaN       NaN
# 2                NaN              NaN  ...           NaN        NaN       NaN
# 3                NaN              NaN  ...           NaN        NaN       NaN
# 4                1.0              6.0  ...           1.0        NaN       NaN
# ..               ...              ...  ...           ...        ...       ...
# 545              NaN              NaN  ...           NaN        NaN       NaN
# 546           1692.0           2878.0  ...           NaN        NaN       NaN
# 547              NaN              NaN  ...           NaN        NaN       NaN
# 548           1088.0           2829.0  ...           NaN        NaN       NaN
# 549              NaN              3.0  ...           NaN        1.0       NaN
#
#      просрочено всего  статус_просрочек  просрочено        bp  monitor_Time  \
# 0                 0.0               1.0         NaN       NaN     2762376.0
# 1               861.0             256.0        50.0  5.120000     3667950.0
# 2                 NaN               NaN         NaN       NaN           NaN
# 3                 NaN               NaN         NaN       NaN     2141948.0
# 4              1976.0             141.0        19.0  7.421053       80139.0
# ..                ...               ...         ...       ...           ...
# 545            3656.0              93.0        46.0  2.021739     2369664.0
# 546           12199.0              20.0        85.0  0.235294     1936264.0
# 547               NaN               NaN         NaN       NaN     1642839.0
# 548              53.0              25.0         8.0  3.125000      971065.0
# 549            9111.0            7841.0      1012.0  7.748024           NaN
#
#      monitorTime_mean  начало_дня
# 0         8073.693333       114.0
# 1         5404.023349       129.0
# 2                 NaN       168.0
# 3          596.958298       125.0
# 4           35.529101        37.0
# ..                ...         ...
# 545        720.741639         NaN
# 546       6290.453890       162.0
# 547       1102.914224         NaN
# 548      15069.358263       137.0
# 549               NaN         NaN
#
# [550 rows x 64 columns]

# %% [markdown]
# # Добавим колличество уникальных профессий

# %%
prof_countis=pd.DataFrame(df_ed.groupby('id')['Специальность'].nunique())
df_train = pd.merge(df_train,prof_countis, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  наприемке  Отложено  \
# 0              176.0            370.0  ...        NaN       NaN
# 1              657.0           1245.0  ...        NaN       NaN
# 2                NaN              NaN  ...        NaN       NaN
# 3                NaN              NaN  ...        NaN       NaN
# 4                1.0              6.0  ...        NaN       NaN
# ..               ...              ...  ...        ...       ...
# 545              NaN              NaN  ...        NaN       NaN
# 546           1692.0           2878.0  ...        NaN       NaN
# 547              NaN              NaN  ...        NaN       NaN
# 548           1088.0           2829.0  ...        NaN       NaN
# 549              NaN              3.0  ...        1.0       NaN
#
#      просрочено всего  статус_просрочек  просрочено        bp  monitor_Time  \
# 0                 0.0               1.0         NaN       NaN     2762376.0
# 1               861.0             256.0        50.0  5.120000     3667950.0
# 2                 NaN               NaN         NaN       NaN           NaN
# 3                 NaN               NaN         NaN       NaN     2141948.0
# 4              1976.0             141.0        19.0  7.421053       80139.0
# ..                ...               ...         ...       ...           ...
# 545            3656.0              93.0        46.0  2.021739     2369664.0
# 546           12199.0              20.0        85.0  0.235294     1936264.0
# 547               NaN               NaN         NaN       NaN     1642839.0
# 548              53.0              25.0         8.0  3.125000      971065.0
# 549            9111.0            7841.0      1012.0  7.748024           NaN
#
#      monitorTime_mean  начало_дня  Специальность
# 0         8073.693333       114.0            1.0
# 1         5404.023349       129.0            1.0
# 2                 NaN       168.0            1.0
# 3          596.958298       125.0            1.0
# 4           35.529101        37.0            1.0
# ..                ...         ...            ...
# 545        720.741639         NaN            NaN
# 546       6290.453890       162.0            1.0
# 547       1102.914224         NaN            NaN
# 548      15069.358263       137.0            2.0
# 549               NaN         NaN            NaN
#
# [550 rows x 65 columns]

# %% [markdown]
# # Добавим оборотные виды документов.

# %%
df_tasks
documents=pd.DataFrame(df_tasks.groupby('id')['Вид документа'].nunique())
df_train = pd.merge(df_train,documents, on="id", how='left')
df_train
# Out:
#              id  type  Вид образования  Число опозданий      CallTime  \
# 0    ОРГ1-02050     2                4              5.0  4.810983e+18
# 1    ОРГ1-02783     2                0              7.0  1.350599e+19
# 2    ОРГ2-06173     0                0             22.0           NaN
# 3    ОРГ2-05359     2               10              6.0           NaN
# 4    ОРГ1-00803     2                0             35.0  1.388889e+17
# ..          ...   ...              ...              ...           ...
# 545  ОРГ1-02587     2               -1              NaN           NaN
# 546  ОРГ1-02383     2                0             54.0  2.259805e+19
# 547  ОРГ1-02862     2               -1              NaN           NaN
# 548  ОРГ1-00471     2               -1             12.0  1.749719e+19
# 549  ОРГ2-02694     2               -1              NaN  1.291306e+17
#
#      NumberOfCalls_worck  NumberOfCalls_free  NumberOfCallsfreesum  \
# 0                  546.0               546.0                   NaN
# 1                 1902.0              1902.0                   NaN
# 2                    NaN                 NaN                   NaN
# 3                    NaN                 NaN                   NaN
# 4                    7.0                 7.0                   NaN
# ..                   ...                 ...                   ...
# 545                  NaN                 NaN                   NaN
# 546               4570.0              4234.0                 336.0
# 547                  NaN                 NaN                   NaN
# 548               3917.0              3638.0                 279.0
# 549                  3.0                 NaN                   NaN
#
#      NumberOfCalls_x  NumberOfCalls_y  ...  Отложено  просрочено всего  \
# 0              176.0            370.0  ...       NaN               0.0
# 1              657.0           1245.0  ...       NaN             861.0
# 2                NaN              NaN  ...       NaN               NaN
# 3                NaN              NaN  ...       NaN               NaN
# 4                1.0              6.0  ...       NaN            1976.0
# ..               ...              ...  ...       ...               ...
# 545              NaN              NaN  ...       NaN            3656.0
# 546           1692.0           2878.0  ...       NaN           12199.0
# 547              NaN              NaN  ...       NaN               NaN
# 548           1088.0           2829.0  ...       NaN              53.0
# 549              NaN              3.0  ...       NaN            9111.0
#
#      статус_просрочек  просрочено        bp  monitor_Time  monitorTime_mean  \
# 0                 1.0         NaN       NaN     2762376.0       8073.693333
# 1               256.0        50.0  5.120000     3667950.0       5404.023349
# 2                 NaN         NaN       NaN           NaN               NaN
# 3                 NaN         NaN       NaN     2141948.0        596.958298
# 4               141.0        19.0  7.421053       80139.0         35.529101
# ..                ...         ...       ...           ...               ...
# 545              93.0        46.0  2.021739     2369664.0        720.741639
# 546              20.0        85.0  0.235294     1936264.0       6290.453890
# 547               NaN         NaN       NaN     1642839.0       1102.914224
# 548              25.0         8.0  3.125000      971065.0      15069.358263
# 549            7841.0      1012.0  7.748024           NaN               NaN
#
#      начало_дня  Специальность  Вид документа
# 0         114.0            1.0            1.0
# 1         129.0            1.0            5.0
# 2         168.0            1.0            NaN
# 3         125.0            1.0            NaN
# 4          37.0            1.0            5.0
# ..          ...            ...            ...
# 545         NaN            NaN            7.0
# 546       162.0            1.0            5.0
# 547         NaN            NaN            NaN
# 548       137.0            2.0            5.0
# 549         NaN            NaN           11.0
#
# [550 rows x 66 columns]

# %% [markdown]
# # Добавим месяцы звонков

# %%
df_calls['monday']=pd.to_datetime(df_calls["Date"]).dt.month
monday_calls=pd.DataFrame(df_calls.groupby('id')['monday'].nunique())
df_train = pd.merge(df_train,monday_calls, on="id", how='left')
df_train

# %% [markdown]
# # Добавим месяцы в сети

# %%
timennetwork['mondayW']=pd.to_datetime(timennetwork['startTime']).dt.month
monday_worck=pd.DataFrame(timennetwork.groupby('id')['mondayW'].nunique())     
df_train = pd.merge(df_train,monday_worck, on="id", how='left')
df_train

# %% [markdown]
# # Добавим месяцы активности за монитором.

# %%
workingday['mondayWork']=pd.to_datetime(workingday['startTime']).dt.month
monday_Work=pd.DataFrame(workingday.groupby('id')['mondayWork'].nunique())     
df_train = pd.merge(df_train,monday_Work, on="id", how='left')
df_train

# %%
workingday

# %% [markdown]
# ## Добавим  дельту дат звонка.

# %%
df_calls
one_cals=pd.DataFrame(df_calls.groupby('id')['Date'].min()).rename(columns={'Date': 'one_cals'})
last_cals=pd.DataFrame(df_calls.groupby('id')['Date'].max()).rename(columns={'Date': 'last_cals'})
last_cals['last_cals_delta']=((pd.to_datetime(last_cals['last_cals'])-pd.to_datetime(one_cals['one_cals'])).dt.days.astype('int'))
last_cals=last_cals.drop(['last_cals'], axis = 1)
df_train = pd.merge(df_train,last_cals, on="id", how='left')
df_train

# %%
df_calls.info()

# %% [markdown]
# # Добавим дельту сети

# %%
timennetwork

# %%
df_calls
one_net=pd.DataFrame(timennetwork.groupby('id')['startTime'].min()).rename(columns={'startTime': 'one_net'})
last_net=pd.DataFrame(timennetwork.groupby('id')['startTime'].max()).rename(columns={'startTime': 'last_net'})
last_net['last_net_delta']=((pd.to_datetime(last_net['last_net'])-pd.to_datetime(one_net['one_net'])).dt.days.astype('int'))
last_net=last_net.drop(['last_net'], axis = 1)
df_train = pd.merge(df_train,last_net, on="id", how='left')
df_train

# %% [markdown]
# # Добавим дельту работы за компьютером

# %%
workingday

# %%
one_worck=pd.DataFrame(workingday.groupby('id')['startTime'].min()).rename(columns={'startTime': 'one_worck'})
last_worck=pd.DataFrame(workingday.groupby('id')['startTime'].max()).rename(columns={'startTime': 'last_worck'})
last_worck['last_worck']
one_worck['one_worck']
last_worck['last_worck_delta']=((pd.to_datetime(last_worck['last_worck'])-pd.to_datetime(one_worck['one_worck'])).dt.days.astype('int'))
last_worck=last_worck.drop(['last_worck'], axis = 1)
df_train = pd.merge(df_train,last_worck, on="id", how='left')
df_train

# %% [markdown]
# # Звонки по месяцам

# %%
for i in range(1,13):
    calls_month_sum=pd.DataFrame(df_calls.query('monday==@i').groupby('id')['CallTime'].mean()).rename(columns={'CallTime': 'calls_month_sum'+ str(i)})
    df_train = pd.merge(df_train,calls_month_sum, on="id", how='left')
df_train

# %% [markdown]
# # Даты окончаний заданий по месмяцам.

# %%
df_tasks

# %%
df_tasks['month']=pd.to_datetime(df_tasks['Дата завершения задания фактическая']).dt.month
for i in range(1,13):
    tasks_month_sum=pd.DataFrame(df_tasks.query('month==@i').groupby('id')['Просрочено, дней'].sum()).rename(columns={'Просрочено, дней': 'tasks_month_sum'+ str(i)})
    df_train = pd.merge(df_train,tasks_month_sum, on="id", how='left')
df_train

# %% [markdown]
# # Добавим сеть по месяцам

# %%
for i in range(6,13):
    net_month_sum=pd.DataFrame(timennetwork.query('mondayW==@i').groupby('id')['monitor_Time'].mean()).rename(columns={'monitor_Time': 'net_month_sum'+ str(i)})
    df_train = pd.merge(df_train,net_month_sum, on="id", how='left')
df_train

# %% [markdown]
# # Добавим работу за компьютером по месяцам

# %%
for i in range(6,13):
    worck_month_sum=pd.DataFrame(workingday.query('mondayWork==@i').groupby('id')['monitorTime'].mean()).rename(columns={'monitorTime': 'worck_month_sum'+ str(i)})
    df_train = pd.merge(df_train,worck_month_sum, on="id", how='left')

# %% [markdown]
# ## Заменим пропуски на нули

# %%
df_train = df_train.fillna(0)

# %%
df_train

# %%
plt.rcParams['figure.figsize']=(30,40)
corr = df_train[df_train.columns[0:14]].corr()
g = sns.heatmap(corr, square = True, annot=True)
plt.title('Корреляции', size=28)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Выделим выборки

# %%
X = df_train.drop(['id', 'type',], axis = 1)
y = df_train["type"]

# %%
X.shape

# %% [markdown]
# # Стандартизация величин!

# %%
scaler = StandardScaler()
scaler.fit(X)
X=scaler.transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# # smote Балансировка датасета.

# %%
sm = SMOTE (random_state=0,k_neighbors=5)
X_train_res, y_train_res = sm.fit_resample (X_train,  y_train,) 
X_train,  y_train = X_train_res, y_train_res

# %% [markdown]
# # Обучение модели

# %%
clf1=OneVsRestClassifier(RandomForestClassifier(max_depth=2,random_state=2))
clf2=OneVsRestClassifier(LogisticRegression(max_iter=500, random_state=2))
clf3=OneVsRestClassifier(GaussianNB(var_smoothing=0.000005))

# %%
eclf1 = VotingClassifier(estimators=[('lr', clf1), ('gnb', clf2),('gnbl', clf3)], voting='hard')
eclf1 = eclf1.fit(X_train, y_train)

# %%
X_train.shape

# %% [markdown]
# nb_classifier = GaussianNB()
#
# params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
# gs_NB = GridSearchCV(estimator=nb_classifier,
#                  param_grid=params_NB,    # use any cross validation technique
#                  verbose=1,
#                  scoring='recall_macro')
# gs_NB.fit(X_train, y_train)
#
# gs_NB.best_params_

# %% [markdown]
# parametrs = {
#               'max_depth':range(1,25),
#               'min_samples_leaf': range (2,15),
#               'min_samples_split': range (2,15,) }
# grid = GridSearchCV(RandomForestClassifier(), parametrs, scoring='recall_macro', cv=10,n_jobs=-1)
# grid.fit(X_train, y_train)
# grid.best_params_

# %% [markdown]
# gb_grid_params = {'max_depth': range(1,20),
#               }
#
# gb_gs = GradientBoostingClassifier(n_estimators = 600)
#
# clf = GridSearchCV(LGBMClassifier(max_depth=3,random_state=2),
#                                gb_grid_params,
#                                cv=2,
#                                scoring='recall_macro',
#                                verbose = 3,
#                                n_jobs=-1);
# clf.fit(X_train, y_train)
# clf.best_params_

# %% [markdown]
# for i in range(1,100):
#     clf=OneVsRestClassifier(RandomForestClassifier(max_depth= 2,n_estimators=i))
#     clf.fit(X_train, y_train)
#     pred = clf.predict(X_test)
#     print(i,"Recall score:", recall_score(y_test, pred, average='macro'))

# %% [markdown]
# for i in range(200,500):
#     clf1=OneVsRestClassifier(RandomForestClassifier(max_depth=2, random_state=2))
#     clf2=OneVsRestClassifier(LogisticRegression(max_iter=i, random_state=2))
#     clf3=OneVsRestClassifier(GaussianNB(var_smoothing=0.000005))
#     eclf1 = VotingClassifier(estimators=[('lr', clf1), ('gnb', clf2),('gnbl', clf3)], voting='hard')
#     eclf1 = eclf1.fit(X_train, y_train)
#     pred = eclf1.predict(X_test)
#     print(i,classification_report(y_test, pred))

# %% [markdown]
# ## Оценка точности

# %%
pred = eclf1.predict(X_test)
pred

# %%
y_test.head(3)

# %%
print("Recall score:", recall_score(y_test, pred, average='macro'))

# %%
print(classification_report(y_test, pred))

# %% [markdown]
# ## Генерация предсказания

# %%
df_test

# %% [markdown]
# ## Добавим фичи.

# %%
df_test = pd.merge(df_test, df_ed , on="id", how='left').drop_duplicates(subset="id")
df_test = df_test.drop(["Табельный номер руководителя", "Специальность"],axis = 1)
df_test["Вид образования"] = df_test["Вид образования"].astype('category')
df_test["Вид образования"] = df_test["Вид образования"].cat.codes
df_test = pd.merge(df_test, df_connection_time_res , on="id", how='left')#.drop(["event_type"],axis =1)

# %% [markdown]
# # Добавим суммарное время звоков

# %%
df_test = pd.merge(df_test, CallTime , on="id", how='left')

# %% [markdown]
# ## Добавим колличество звонков в будни и выходные дни

# %%
df_test = pd.merge(df_test, NumberOfCalls , on="id", how='left')
df_test = pd.merge(df_test, NumberOfCallsW , on="id", how='left')
df_test = pd.merge(df_test, NumberOfCallsNW , on="id", how='left')
df_test = df_test.rename(columns={'NumberOfCalls_x': 'NumberOfCalls_worck','NumberOfCalls_y': 'NumberOfCalls_free','NumberOfCalls': 'NumberOfCallsfreesum'})

# %% [markdown]
# ## Добавим колличество входящих и исходящих

# %%
df_test = pd.merge(df_test, NumberToUser , on="id", how='left')
df_test = pd.merge(df_test, NumberFromUser , on="id", how='left')

# %% [markdown]
# # Добавим суммарное время опоздания

# %%
df_test = pd.merge(df_test, falout , on="id", how='left')

# %% [markdown]
# # Добавим дельту прихода на работу

# %%
df_test  = pd.merge(df_test, filtime , on="id", how='left')

# %% [markdown]
# # Добавим профессию

# %%
profession=df_ed[['id','Специальность']].groupby('id')['Специальность'].min()
df_test = pd.merge(df_test, professionstart , on="id", how='left')
df_test = pd.merge(df_test, professionend , on="id", how='left')

# %%
df_test.head()

# %% [markdown]
# ## Добавим колличество руководителей

# %%
df_test = pd.merge(df_test, boss , on="id", how='left')

# %% [markdown]
# # Добавим колличество завершенных заданий.

# %%
df_test = pd.merge(df_test,status_mission_count, on="id", how='left')
df_test = pd.merge(df_test,status_mission_count_in, on="id", how='left')
for i in range(1,13):
    tasks_month_sum_start=pd.DataFrame(df_tasks.query("status_mission_count=='В работе'").query('month==@i').groupby('id')['Дата старта задания'].nunique()).rename(columns={'Дата старта задания': 'tasks_month_sum_start'+ str(i)})
    df_test = pd.merge(df_test,tasks_month_sum_start, on="id", how='left')
for i in range(1,13):
    tasks_month_sum_end=pd.DataFrame(df_tasks.query("status_mission_count=='Завершено'").query('monthstart==@i').groupby('id')['Дата старта задания'].nunique()).rename(columns={'Дата старта задания': 'tasks_month_sum_end'+ str(i)})
    df_test = pd.merge(df_test,tasks_month_sum_end, on="id", how='left')
df_test = pd.merge(df_test,status_mission_count_nn, on="id", how='left')
for i in range(1,13):
    tasks_month_sum_startn=pd.DataFrame(df_tasks.query("status_mission_count=='Делегировано'").query('monthstart==@i').groupby('id')['Дата старта задания'].nunique()).rename(columns={'Дата старта задания': 'tasks_month_sum_startn'+ str(i)})
    df_test = pd.merge(df_test,tasks_month_sum_startn, on="id", how='left')
df_train
df_test = pd.merge(df_test,status_mission_count_d, on="id", how='left')
df_test = pd.merge(df_test,status_mission_count_p, on="id", how='left')
df_test = pd.merge(df_test,status_mission_count_o, on="id", how='left')

# %% [markdown]
# # Добавим сумму просроченных дней

# %%
df_test = pd.merge(df_test,day_ful_mission, on="id", how='left')

# %% [markdown]
# # Добавим статус по просрочке с нарушением без науршения и их отношение.

# %%
df_test = pd.merge(df_test,fail_count_b, on="id", how='left')
df_test = pd.merge(df_test,fail_count_p, on="id", how='left')
df_test['bp']=df_test['статус_просрочек']/df_test['просрочено']

# %% [markdown]
# # Добавим общее время активности в сети.

# %%
df_test = pd.merge(df_test,timennetwork_time, on="id", how='left')

# %% [markdown]
# # Добавим среднее время простоя монитора

# %%
df_test = pd.merge(df_test,monitor_stop, on="id", how='left')

# %% [markdown]
# # Добавим счетчик начала рабочего дня

# %%
df_test = pd.merge(df_test,start_day, on="id", how='left')

# %% [markdown]
# ## Добавим колличество уникальных специальностей

# %%
df_test = pd.merge(df_test,prof_countis, on="id", how='left')

# %% [markdown]
# # Добавим оборотные виды документов

# %%
df_test = pd.merge(df_test,documents, on="id", how='left')

# %% [markdown]
# # Добавим месяцы звонков

# %%
df_test = pd.merge(df_test,monday_calls, on="id", how='left')

# %% [markdown]
# # Добавим месяцы в сети

# %%
df_test = pd.merge(df_test,monday_worck, on="id", how='left')

# %% [markdown]
# # Добавим месяцы активности за монитором

# %%
df_test = pd.merge(df_test,monday_Work, on="id", how='left')

# %% [markdown]
# # Добавим дельту дат звонка

# %%
df_test = pd.merge(df_test,last_cals, on="id", how='left')

# %% [markdown]
# # Добавим дельту сети

# %%
df_test = pd.merge(df_test,last_net, on="id", how='left')

# %% [markdown]
# # Добавим дельту работы за компьютером

# %%
df_test = pd.merge(df_test,last_worck, on="id", how='left')

# %% [markdown]
# # Звонки по месяцам

# %%
for i in range(1,13):
    calls_month_sum=pd.DataFrame(df_calls.query('monday==@i').groupby('id')['CallTime'].mean()).rename(columns={'CallTime': 'calls_month_sum'+ str(i)})
    df_test = pd.merge(df_test,calls_month_sum, on="id", how='left')
df_test

# %% [markdown]
# # Даты окончаний заданий по месяцам.

# %%
for i in range(1,13):
    tasks_month_sum=pd.DataFrame(df_tasks.query('month==@i').groupby('id')['Просрочено, дней'].sum()).rename(columns={'Просрочено, дней': 'tasks_month_sum'+ str(i)})
    df_test = pd.merge(df_test,tasks_month_sum, on="id", how='left')
df_test

# %% [markdown]
# # Добавим сеть по месяцам

# %%
for i in range(6,13):
    net_month_sum=pd.DataFrame(timennetwork.query('mondayW==@i').groupby('id')['monitor_Time'].mean()).rename(columns={'monitor_Time': 'net_month_sum'+ str(i)})
    df_test = pd.merge(df_test,net_month_sum, on="id", how='left')
df_test

# %% [markdown]
# # Добавим работу за компьютером по месяцам

# %%
for i in range(6,13):
    worck_month_sum=pd.DataFrame(workingday.query('mondayWork==@i').groupby('id')['monitorTime'].mean()).rename(columns={'monitorTime': 'worck_month_sum'+ str(i)})
    df_test = pd.merge(df_test,worck_month_sum, on="id", how='left')
df_test

# %% [markdown]
# # Удалим пустые значения

# %%
df_test = df_test.fillna(0)

# %%
df_test

# %% [markdown]
# ## Предсказания

# %%
df_test_pred = pd.read_csv("test.csv")
Xpred = df_test.drop(['id', 'type'], axis = 1)
Xpred=scaler.transform(Xpred)
preds = eclf1.predict(Xpred)
df_test_pred['type']=preds

# %%
df_test_pred.to_csv('bestmodel2.csv', index=False)

# %%
df_test_pred['type'].value_counts()
